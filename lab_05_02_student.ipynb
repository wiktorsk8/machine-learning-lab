# %% [markdown]
# # LAB 5.2: Systemy Ekspertowe (Forward Chaining)

# %%
class RuleEngine:
    def __init__(self):
        self.facts = set()
        self.rules = []

    def add_fact(self, fact):
        self.facts.add(fact)

    def add_rule(self, conditions, result):
        self.rules.append({'if': set(conditions), 'then': result})

    def infer(self):
        # TODO: Zaimplementuj wnioskowanie w przód (Forward Chaining)
        # Dopóki dodawane są nowe fakty:
        #   Sprawdź każdą regułę
        #   Jeśli warunki są spełnione (issubset) i wniosek nieznany -> dodaj fakt
        pass

# Test
engine = RuleEngine()
engine.add_fact('katar')
engine.add_fact('goraczka')
engine.add_rule(['katar', 'goraczka'], 'grypa')

engine.infer()
print('Fakty:', engine.facts)
