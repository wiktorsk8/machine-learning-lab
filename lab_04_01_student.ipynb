# %% [markdown]
# # LAB 4.1: Algorytmy Genetyczne
# **Temat:** Implementacja AG od zera

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)
print('✓ Setup')

# %%
class GeneticAlgorithm:
    def __init__(self, fitness_func, gene_length, population_size=100, mutation_rate=0.01, crossover_rate=0.7):
        self.fitness_func = fitness_func
        self.gene_length = gene_length
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.population = np.random.randint(0, 2, (population_size, gene_length))

    def selection(self, fitness_scores):
        # TODO: Zaimplementuj selekcję turniejową (Tournament Selection)
        # 1. Wylosuj k osobników (np. k=3)
        # 2. Wybierz tego z najlepszym fitnessem
        return self.population[np.random.randint(self.population_size)] # Placeholder

    def crossover(self, parent1, parent2):
        # TODO: Zaimplementuj krzyżowanie jednopunktowe (One-Point Crossover)
        if np.random.random() < self.crossover_rate:
            # point = ...
            pass
        return parent1, parent2

    def mutate(self, individual):
        # TODO: Zaimplementuj mutację bitową (Bit Flip Mutation)
        # Dla każdego genu, jeśli losowa liczba < mutation_rate -> odwróć bit
        return individual

    def evolve(self, generations=100):
        best_history = []
        for _ in range(generations):
            # TODO: Główna pętla algorytmu
            # 1. Oblicz fitness
            # 2. Utwórz nową populację przez selekcję, krzyżowanie i mutację
            pass
        return best_history

# %%
# TODO: Zdefiniuj funkcję fitness (np. One-Max: suma jedynek) i uruchom algorytm
def onemax(ind):
    return np.sum(ind)

ga = GeneticAlgorithm(onemax, gene_length=50)
# history = ga.evolve()
# plt.plot(history)
