# %% [markdown]
# # LAB 3.3: Model Evaluation & Hyperparameter Tuning
#
# **Czas:** 2h

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV, learning_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score
from sklearn.preprocessing import StandardScaler

np.random.seed(42)
print('✓ Setup')

# %% [markdown]
# ## CZĘŚĆ 1: Cross-Validation (30 min)

# %%
# TODO: Wczytaj dane Breast Cancer, podziel na train/test i przeskaluj
X_train_scaled, X_test_scaled, y_train, y_test = None, None, None, None # TODO

# %%
# TODO: Użyj cross_val_score z modelem RandomForest (cv=5)
rf = RandomForestClassifier(n_estimators=100, random_state=42)
scores = None # TODO

# if scores is not None:
#     print(f'Mean CV score: {scores.mean():.4f}')

# %% [markdown]
# ## CZĘŚĆ 2: Grid Search (30 min)

# %%
# TODO: Zdefiniuj siatkę parametrów dla Random Forest
# parametry: n_estimators, max_depth, min_samples_split
param_grid = {
    # TODO
}

# TODO: Skonfiguruj GridSearchCV
rf_grid = None # TODO
# rf_grid.fit(X_train_scaled, y_train)

# TODO: Wyświetl najlepsze parametry (best_params_) i wynik (best_score_)

# %% [markdown]
# ## CZĘŚĆ 3: Random Search (20 min)

# %%
from scipy.stats import randint

# TODO: Zdefiniuj rozkłady parametrów dla RandomizedSearchCV
param_dist = {
    # 'n_estimators': randint(50, 300),
    # ... TODO
}

# TODO: Uruchom RandomizedSearchCV (n_iter=50)
rf_random = None # TODO

# %% [markdown]
# ## CZĘŚĆ 4: Learning Curves (30 min)

# %%
# TODO: Wygeneruj krzywe uczenia używając learning_curve
# train_sizes, train_scores, val_scores = learning_curve(...)
pass

# %% [markdown]
# ## CZĘŚĆ 5: ROC Curve (10 min)

# %%
# TODO: Oblicz prawdopodobieństwa klas (predict_proba) i narysuj krzywą ROC
# y_proba = ...
# fpr, tpr, thresholds = roc_curve(y_test, y_proba)
pass
