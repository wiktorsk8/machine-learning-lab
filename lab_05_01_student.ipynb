# %% [markdown]
# # LAB 5.1: Decision Trees & Random Forest

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

print('✓ Setup')

# %%
# TODO: Wczytaj Iris dataset i podziel na train/test
iris = load_iris()
X, y = iris.data, iris.target
X_train, X_test, y_train, y_test = None, None, None, None # TODO

# %%
# TODO: Wytrenuj Drzewo Decyzyjne (max_depth=3)
dt = None # TODO

# TODO: Sprawdź accuracy
# print(accuracy_score(...))

# %%
# TODO: Zwizualizuj drzewo używając plot_tree
plt.figure(figsize=(15,10))
# plot_tree(...)
plt.show()

# %%
# TODO: Wytrenuj Random Forest i wyświetl Feature Importance
rf = None # TODO
# rf.fit(...)

# importance = rf.feature_importances_
# plt.barh(...)
